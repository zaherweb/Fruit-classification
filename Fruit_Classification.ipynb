# %% [markdown]
# <a href="https://colab.research.google.com/github/zaherweb/Fruit-classification/blob/main/Fruit_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fruit Classification
# This project is part from our work with MR.Chris in upwork , This model contains only 4 classes but final model will contains more than that.
# This is a link to Kaggle train  [Notebook](https://www.kaggle.com/code/mahmoudzaher/fruit-fresh-and-rotten/edit)

# %%
cd "/content/drive/MyDrive/upwork/Chris/fruit "
# Out:
# /content/drive/MyDrive/upwork/Chris/fruit

# %%
from keras.models import load_model
from keras.models import model_from_json
import matplotlib.pyplot as plt
from keras.applications import imagenet_utils
import numpy as np

# %% [markdown]
# # Loading the model and preprocessing

# %%
#define main classes that we have
classes = [ "Rotten Banana", "Good Banana", "Rotten Orange", "Good Orange" ] 
# load json and create model
json_file = open('model3.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model1 = model_from_json(loaded_model_json)
# load weights into new model
loaded_model1.load_weights("model.h5")


#Main Function of prediction
def predict_type(location):
    img=load_img(location,target_size=(224,224,3))
    plt.imshow(img)
    img=img_to_array(img)
    
    img=img/255
    plt.imshow(img)
    img=np.expand_dims(img,[0])
    
    answer=loaded_model1.predict(img)
    #To print prediction list
    #print(answer)

    y_class = answer.argmax(axis=-1)
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = classes[y]
    return res

# %%
# %%writefile "/content/drive/MyDrive/upwork/Chris/fruit /prediction.py"
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.preprocessing.image import load_img,img_to_array
# from skimage.transform import resize
# import numpy as np
#
# from PIL import Image
# import time
# from keras.models import load_model
# from keras.models import model_from_json
# from keras.applications import imagenet_utils
# from prediction import predict_type
#
#
#
# #define main classes that we have
# classes = [ "Rotten Banana", "Good Banana", "Rotten Orange", "Good Orange" ]
# # load json and create model
# json_file = open('model3.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model1 = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model1.load_weights("model.h5")
#
# #Main Function of prediction
# def predict_type(location):
#     img=load_img(location,target_size=(224,224,3))
#     #plt.imshow(img)
#     img=img_to_array(img)
#
#     img=img/255
#     #plt.imshow(img)
#     img=np.expand_dims(img,[0])
#
#     answer=loaded_model1.predict(img)
#     #To print prediction list
#     #print(answer)
#
#     y_class = answer.argmax(axis=-1)
#     y = " ".join(str(x) for x in y_class)
#     y = int(y)
#     res = classes[y]
#     return res
# Out:
# Overwriting /content/drive/MyDrive/upwork/Chris/fruit /prediction.py

# %% [markdown]
# # Predicting Image

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img,img_to_array

#from tensorflow.keras.preprocessing.image import load_img,img_to_array

img="/content/drive/MyDrive/upwork/Chris/fruit /Test Image Sample/IMG_7701.jpg"
pic=image.load_img(img,target_size=(224,224,3))
#plt.imshow(pic)
print(predict_type(img))
# Out:
# 1/1 [==============================] - 2s 2s/step
# Rotten Banana

# %%
sample_folder = "/content/drive/MyDrive/upwork/Chris/fruit /Test Image Sample"
# Out:
# /bin/bash: line 0: cd: sample_folder: No such file or directory

# %%
# test on multi image
import os 

for i in os.listdir(sample_folder):
  i = sample_folder + "/" + i
  pic=image.load_img(i,target_size=(224,224,3))
  print(predict_type(i))
# Out:
# 1/1 [==============================] - 0s 131ms/step
# Rotten Orange
# 1/1 [==============================] - 0s 129ms/step
# Rotten Banana
# 1/1 [==============================] - 0s 165ms/step
# Good Banana
# 1/1 [==============================] - 0s 148ms/step
# Rotten Banana

# %% [markdown]
# # Run streamlit app from a Google Colab Notebook
# > Created by [Manuel Romero](https://twitter.com/mrm8488)

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 101.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 107.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.7 MB/s eta 0:00:00
#   Building wheel for validators (setup.py) ... done

# %% [markdown]
# ## Install localtunnel

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/drive/MyDrive/upwork/Chris/fruit /package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/drive/MyDrive/upwork/Chris/fruit /package.json'
# npm WARN fruit  No description
# npm WARN fruit  No repository field.
# npm WARN fruit  No README data
# npm WARN fruit  No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 5.583s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %% [markdown]
# ## Create a streamlit app example

# %%
#https://towardsdatascience.com/how-to-build-an-image-classification-app-using-logistic-regression-with-a-neural-network-mindset-1e901c938355

# %%
cd "/content/drive/MyDrive/upwork/Chris/fruit /"
# Out:
# /content/drive/MyDrive/upwork/Chris/fruit

# %% [markdown]
# ## Call of the model from the web app

# %%
# %%writefile "/content/drive/MyDrive/upwork/Chris/fruit /app.py"
#
#
# #importing the libraries
# import streamlit as st
# import joblib
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.preprocessing.image import load_img,img_to_array
#
# from PIL import Image
# from skimage.transform import resize
# import numpy as np
# import time
# from keras.models import load_model
# from keras.models import model_from_json
# from keras.applications import imagenet_utils
# import numpy as np
# #from prediction import predict_type
#
#
#
# #define main classes that we have
# classes = [ "Rotten Banana", "Good Banana", "Rotten Orange", "Good Orange" ]
# # load json and create model
# json_file = open('model3.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model1 = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model1.load_weights("model.h5")
#
# #Main Function of prediction
# def predict_type(location):
#     img=load_img(location,target_size=(224,224,3))
#     #plt.imshow(img)
#     img=img_to_array(img)
#
#     img=img/255
#     #plt.imshow(img)
#     img=np.expand_dims(img,[0])
#
#     answer=loaded_model1.predict(img)
#     #To print prediction list
#     #print(answer)
#
#     y_class = answer.argmax(axis=-1)
#     y = " ".join(str(x) for x in y_class)
#     y = int(y)
#     res = classes[y]
#     return res
#
#
#
# # Designing the interface
# #st.title(' :blue[   Agrocommercial ] ')
# #st.header("Fruit Image Classification App")
#
# st.markdown("<h1 style='text-align: center; color: blue;'>Agrocommercial</h1>", unsafe_allow_html=True)
#
# st.markdown("<h3 style='text-align: center; color: black;'>Fruit Image Classification App</h2>", unsafe_allow_html=True)
#
# # For newline
# st.write('\n')
#
# image = Image.open('1675237883685.jpg')
# show = st.image(image, use_column_width=True)
#
# st.sidebar.title("Upload Image")
#
# #Disabling warning
# st.set_option('deprecation.showfileUploaderEncoding', False)
# #Choose your own image
# uploaded_file = st.sidebar.file_uploader(" ",type=['png', 'jpg', 'jpeg'] )
#
# if uploaded_file is not None:
#  #########################################################
#     u_img = Image.open(uploaded_file)
#     show.image(u_img, 'Uploaded Image', use_column_width=True)
#     # We preprocess the image to fit in algorithm.
#     #image = np.asarray(u_img)/255
#
#     #my_image= resize(image, (64,64)).reshape((1, 64*64*3)).T
#
# # For newline
# st.sidebar.write('\n')
#
# if st.sidebar.button("Click Here to Classify"):
#
#     if uploaded_file is None:
#
#         st.sidebar.write("Please upload an Image to Classify")
#
#     else:
#
#         with st.spinner('Classifying ...'):
#
#             prediction =predict_type(uploaded_file)
#             time.sleep(2)
#             st.success('Done!')
#
#         st.sidebar.header("Algorithm Predicts: ")
#
#         #Formatted probability value to 3 decimal places
#         #probability = "{:.3f}".format(float(prediction*100))
#
#         # Classify cat being present in the picture if prediction > 0.5
#
#
#         st.markdown(f"<h2 style='text-align: center; color: blue;'>I think this is a {prediction} </h1>", unsafe_allow_html=True)
#         st.sidebar.write("It's a ", prediction,'\n' )
# Out:
# Overwriting /content/drive/MyDrive/upwork/Chris/fruit /app.py

# %%
! pip3 freeze app.py > requirements.txt

# %% [markdown]
# ## Run streamlit in background

# %%
# !streamlit run "/content/drive/MyDrive/upwork/Chris/fruit /app.py" &>"/content/drive/MyDrive/upwork/Chris/fruit /logs.txt" &

# %% [markdown]
# ## Expose the port 8501
# Then just click in the `url` showed.
#
# A `log.txt`file will be created.

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.346s
# your url is: https://honest-maps-jam-34-86-205-60.loca.lt
# ^C
